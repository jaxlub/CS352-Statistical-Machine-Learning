# %%
from transformers import pipeline

# https://huggingface.co/Helsinki-NLP/opus-mt-en-fr
# dataset opus

# %%
en_to_fr = pipeline(task = "translation_en_to_fr", model = "Helsinki-NLP/opus-mt-en-fr")

# %%
en_to_fr("This is a test translation")
# Out:
# [{'translation_text': "Il s'agit d'une traduction de test"}]
