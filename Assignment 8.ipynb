# %% [markdown]
# # Sentiment analysis
#
# The HuggingFace repository contains lots of language models that have been tuned for sentiment analysis (on various datasets).
# - Find one of the models that was tuned on the IMDB movie review dataset.
#
# MICADEE/autonlp-imdb-sentiment-analysis2-7121569
# - Is the model's accuracy reported? How does it compare to our own models?
#
# Accuracy 0.9271 - the highest accuracy we got in class was ~0.88 so this is  stronger then our best models.
#
# - Find a few movie reviews that are too new to be in the dataset.
#
# Dune 2 reviews
# - Create a transformers pipeline and try classifying them. How does it do?

# %%
from transformers import pipeline
imdb_review = pipeline("text-classification", model="MICADEE/autonlp-imdb-sentiment-analysis2-7121569")
# 5 star Dune 2 review
imdb_review("This is one of the best cinematic experiences I’ve ever had. It’s up there with Infinity War for me. There was a little bit of comedy which was great. It really made me start thinking about fate, free will, grand schemes, power, control, and life in general. I’ve not read the books so the themes really started to come together for me in this film, and I understand why the Dune book lovers feel the way they do. I’ll have to give them a read. Not only that, the cinematography was amazing. I felt so in the moment with each scene, because it thrusts you into something new a lot, that I was trying to catch up and understand what was now going on. But it was executed really well. I definitely need to watch it again.")
# Out:
# [{'label': 'positive', 'score': 0.9974127411842346}]

# %%
# 3 star dune 2 review
imdb_review("On one hand, I loved the movie. My heart was thumping the entire time and it did not feel like a 3-hour movie. Keep in mind, I LOVE the Dune story. I have been waiting for this movie since I saw the first one. I know all the lines, the music and even Chakobsa words. I love the arc of Paul's character and his inner struggles. I love how he comes to grips with his fate and how he finally surrenders to it. After all, that is what it means to be human. However, despite all this, the movie does not convince me that Paul TRULY believes he is the Kwisatz Haderach. Even in the end, when he gains control of it all, it still feels that he is doing it only to avenge his father. He has taken the Water of Life, tapped into an omnipotent consciousness and convinced all around him, but he has not convinced HIMSELF. Like Stilgar, we all see the SIGNS, except the ONE himself. I'm not sure if this is because of his love for Chani, who fights against the prophecy with every fiber of her being; or his hate for the Bene Gesserit and their calculated manipulations of mankind's actions and beliefs. I have to say, I enjoyed the movie, but I was hoping for a hero that despite his self doubts, will eventually make the leap and embrace who HE REALLY IS")
# Out:
# [{'label': 'positive', 'score': 0.9953590035438538}]

# %%
# 1 star dune 2 review
imdb_review("So much of the politics of our time has been channeled into this film. Besides being a thinly veiled provocation for conflict instead of an entertaining film, there is such obvious hatred born of envy that it is impossible to even sympathize with the underdog point of view. There is also a noticeable lack of chemistry between the actors and non at all between Paul and Chani. The costumes and behavior of the Gesserit bring such a strong sense of ick that seeing them on the screen draws attention away from the plot, a telltale symptom of the victimhood culture and narcissism so alive in the ism that shall not be named. I never understood how there could be spaceships but only swords for fighting. I nodded off twice while watching the scenes in the desert. Those having such a love for the desert should consider going back to it. The only drifts that belong here are made of snow.")
# Out:
# [{'label': 'negative', 'score': 0.8720415234565735}]

# %%
imdb_review("I love this movie. I hate this movie.")
# Out:
# [{'label': 'positive', 'score': 0.9957478642463684}]

# %%
imdb_review("I want nachos")
# Out:
# [{'label': 'positive', 'score': 0.5458182692527771}]

# %%
imdb_review("I dont want nachos")
# Out:
# [{'label': 'negative', 'score': 0.9244643449783325}]

# %% [markdown]
# Model appears to be very good at IDing of reviews. I was curious about how it would do on 3 star (middle reviews) and it was still very confident. The 1 star review I was impressed with as I chose one that did not say outright "this dissappointed me" or "was a horrible film" and it still classified it correctly. I tried to find some short ones because I think it would have harder time so I made some up (as well as unrelated or almost random ones). I thought it was intresting how love is not canceled by hate word. I also thought it intresting in the last 2 how dont makes it negative with high score while not having dont is positive but low score.

# %% [markdown]
# # Question answering
#
# Question answering is a language task that involves finding the answer to a factual question within provided text.
#
# Model: consciousAI/question-answering-roberta-base-s-v2
#
# The HuggingFace repository contains lots of language models that that have been tuned for question answering.
# - Find one of these models. Which dataset was used to tune it?
#
# SQUAD Split data
# - Investigate the dataset to see what the instances are like.
#
# SQUAD is the  Stanford Question Answering Dataset and contains a wikipedia segment, a question with the answer in the wikipedia segment and the answer to the question.
# - Find some comparable text that is too new to be in the dataset.
#
#   Dune 2 wikipedia page
# - Create a transformers pipeline and try asking a few questions. How does it do?

# %%
squad = pipeline("question-answering", model="consciousAI/question-answering-roberta-base-s-v2")

# %%
context = "Dune: Part Two is a 2024 American epic science fiction film directed and produced by Denis Villeneuve, who co-wrote the screenplay with Jon Spaihts. The sequel to Dune (2021), it is the second of a two-part adaptation of the 1965 novel Dune by Frank Herbert. It follows Paul Atreides as he unites with the Fremen people of the desert planet Arrakis to wage war against House Harkonnen. Timothée Chalamet, Zendaya, Rebecca Ferguson, Josh Brolin, Dave Bautista, Stellan Skarsgård, Charlotte Rampling, and Javier Bardem reprise their roles from the first film, with Austin Butler, Florence Pugh, Christopher Walken, Léa Seydoux, and Souheila Yacoub joining the ensemble cast."

question = "When was dune the book written?"

squad(question=question, context=context)
# Out:
# {'score': 0.9997292160987854, 'start': 225, 'end': 229, 'answer': '1965'}

# %%
question = "Who is the main character in Dune?"
squad(question=question, context=context)
# Out:
# {'score': 0.9995154738426208,
#  'start': 270,
#  'end': 283,
#  'answer': 'Paul Atreides'}

# %%
question = "Who are the Fremen?"
squad(question=question, context=context)
# Out:
# {'score': 0.5740929841995239,
#  'start': 302,
#  'end': 348,
#  'answer': 'the Fremen people of the desert planet Arrakis'}

# %%
question = "Who is House Harkonnen?"
squad(question=question, context=context)
# Out:
# {'score': 0.1496160924434662,
#  'start': 270,
#  'end': 283,
#  'answer': 'Paul Atreides'}

# %% [markdown]
# The first two questions were fairly simple and was cool when it got them (and score of .999 on both). As these were basic answers it did very well. The last 2 question I chose because there was not a whole lot of data for the answer and is longer then a word or two. I was very impressed with its response to Q3 but you can see the model scored this answer much lower and the answer was very vague. In Q4 there is no data on House Harkennen and based off this passage the best answer would be along the lines of "the people who freman wage war against". The model on this question has a very low score and spits out the wrong answer but I didnt really expect it to get this question.

# %% [markdown]
# # Summarization
#
# Summarization is a language task that involves shortening provided text to convey just the most important information.
#
# The HuggingFace repository contains lots of language models that that have been tuned for summarization.
# - Find one of these models. Which dataset was used to tune it?
#
# Dataset is "Various scientific and news articles, along with our own custom dataset" according to authors.
# - Investigate the dataset to see what the instances are like.
#
# Dataset includes documents with passages and then their human-generated summarizations.
# - Find a few comparable texts that are too new to be in the dataset.
#
# Dune 2 Wikipedia
# - Create a transformers pipeline and try summarizing them. How does it do?

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="Falconsai/text_summarization")

ARTICLE = """
Dune: Part Two is a 2024 American epic science fiction film directed and produced by Denis Villeneuve, who co-wrote the screenplay with Jon Spaihts. The sequel to Dune (2021), it is the second of a two-part adaptation of the 1965 novel Dune by Frank Herbert. It follows Paul Atreides as he unites with the Fremen people of the desert planet Arrakis to wage war against House Harkonnen. Timothée Chalamet, Zendaya, Rebecca Ferguson, Josh Brolin, Dave Bautista, Stellan Skarsgård, Charlotte Rampling, and Javier Bardem reprise their roles from the first film, with Austin Butler, Florence Pugh, Christopher Walken, Léa Seydoux, and Souheila Yacoub joining the ensemble cast.
Development began after Legendary Entertainment acquired film and television rights for the Dune franchise in 2016. Villeneuve signed on as director in 2017, intending to make a two-part adaptation of the novel due to its complexity. Production contracts were only secured for the first film, with the second film having to be greenlit based on the first's success. Villeneuve was concerned about the sequel's certainty after the first film had a simultaneous theatrical and HBO Max release but Warner Bros. Pictures assured him the sequel would happen if it performed well on HBO Max. After the critical and commercial success of the first film, Warner Bros. and Legendary green-lit Dune: Part Two in October 2021. Principal photography took place in Budapest, Italy, Jordan, and Abu Dhabi between July and December 2022.
After being delayed from an original November 2023 release date due to the 2023 Hollywood labor disputes, the film premiered at the Odeon Luxe Leicester Square, London, on February 15, 2024, and was released in the United States on March 1. It received praise from critics and has grossed over $696 million worldwide, making it the highest-grossing film of 2024. A sequel based on Herbert's 1969 novel Dune Messiah is in development.
"""
print(summarizer(ARTICLE, max_length=100, min_length=30, do_sample=False))
# Out:
# [{'summary_text': 'Dune: Part Two is the second of a two-part adaptation of the 1965 novel Dune by Frank Herbert . It follows Paul Atreides as he unites with the Fremen people of the desert planet Arrakis to wage war against House Harkonnen . Timothée Chalamet, Zendaya, Rebecca Ferguson, Josh Brolin, Dave Bautista, Stellan Skarsgrd, Charlotte Rampling'}]

# %%
print(summarizer(ARTICLE, max_length=50, min_length=20, do_sample=False))
# Out:
# [{'summary_text': 'Dune: Part Two is the second of a two-part adaptation of the 1965 novel Dune by Frank Herbert . It follows Paul Atreides as he unites with the Fremen people of the desert planet Arrakis'}]

# %%
print(summarizer(ARTICLE, max_length=20, min_length=15, do_sample=False))
# Out:
# [{'summary_text': 'Denis Villeneuve co-wrote the screenplay with Jon Spaihts '}]

# %%
print(summarizer(ARTICLE, max_length=10, min_length=1, do_sample=False))
# Out:
# [{'summary_text': 'Dune: Part Two is a 20'}]

# %%
ARTICLE = """
Following the destruction of House Atreides by House Harkonnen,[a] Princess Irulan, the daughter of Padishah Emperor Shaddam IV, secretly journals that Paul Atreides may still be alive. On Arrakis, Stilgar's Fremen troops, including Paul and his pregnant mother, Lady Jessica, overcome a Harkonnen patrol. When Jessica and Paul reach Sietch Tabr, some Fremen suspect they are spies, while Stilgar and others see signs of the prophecy that a mother and son from the "Outer World" will bring prosperity to Arrakis.
Stilgar tells Jessica that Sietch Tabr's Reverend Mother is dying and that Jessica must succeed her by drinking the Water of Life—a poison fatal for males and untrained women. Jessica transmutes and survives the poison, inheriting the memories of all the past Reverend Mothers. The liquid also prematurely awakens the mind of her unborn daughter, Alia, allowing Jessica to communicate with her. They agree to focus on convincing the more skeptical northern Fremen of the prophecy. Chani and her friend, Shishakli, believe the prophecy was fabricated to manipulate the Fremen. However, she begins to respect Paul after he declares that he only intends to fight alongside the Fremen, not to rule them.
Paul and Chani fall in love as Paul immerses himself in Fremen culture: learning their language, becoming a Fedaykin fighter, riding a sandworm, and raiding against Harkonnen spice operations. Paul adopts the Fremen names "Usul" and "Muad'Dib". Due to the devastating spice raids, Baron Vladimir Harkonnen replaces his nephew, Glossu Rabban, as Arrakis's ruler with his more cunning yet psychotic younger nephew, Feyd-Rautha. Lady Margot Fenring, a Bene Gesserit, is sent to evaluate Feyd-Rautha as a prospective Kwisatz Haderach and to secure his genetic lineage.
Jessica travels south to unite with Fremen fundamentalists who believe in the prophecy. Paul remains in the north, fearful that his visions of a holy war will occur if he goes south as a messiah. During another raid on a spice harvester, Paul reunites with Gurney Halleck, with each having presumed the other dead since their separation. Gurney leads Paul to the hidden atomic stockpile of House Atreides. Feyd-Rautha unleashes a devastating attack on the northern Fremen, including Sietch Tabr, forcing Paul and the survivors to journey south. Shishakli remains and Feyd-Rautha executes her. Upon arrival, Paul drinks the Water of Life and falls into a coma. This angers Chani, but she is compelled by Jessica to mix her tears with the liquid, which awakens him. Paul now has clairvoyance across space and time; he envisions an adult Alia on water-filled Arrakis, perceiving a singular path to victory among all possible futures, and discovering that Jessica is the Baron's daughter.
Paul meets with a southern Fremen war council, galvanizing the crowd by demonstrating his ability to discern their deepest thoughts. He declares himself the Lisan al Gaib and sends a challenge to Shaddam, who arrives on Arrakis with Irulan and the Sardaukar. As Shaddam chastises the Harkonnens for their failures, the Fremen launch an offensive using atomics and sandworms to overpower the Sardaukar. Paul executes the Baron, capturing Shaddam and his entourage. Meanwhile, Gurney intercepts and kills a fleeing Rabban.
Paul challenges Shaddam for the throne and, to Chani's dismay, demands to marry Irulan. Previously summoned by the Baron, the Great Houses arrive in orbit. Paul threatens to destroy the spice fields with atomics if they intervene. Feyd-Rautha volunteers to be Shaddam's champion, but Paul kills him in a duel. Irulan agrees to Paul's request for marriage on the condition that her father lives. Shaddam reluctantly surrenders, kneeling, and kisses Paul's signet ring. When the Great Houses reject Paul's ascendancy, he orders the Fremen to attack the orbiting fleet. As Stilgar leads the Fremen onto the captured Sardaukar ships, Jessica and Alia reflect on the beginning of Paul's holy war. Chani refuses to bow to Paul and departs alone on a sandworm.
"""
print(summarizer(ARTICLE, max_length=50, min_length=20, do_sample=False))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1105 > 512). Running this sequence through the model will result in indexing errors
# [{'summary_text': "Paul Atreides is the daughter of Padishah Emperor Shaddam IV . Stilgar's Fremen troops, including Paul and his pregnant mother, Lady Jessica, secretly journals . They believe the prophecy"}]

# %%
print(summarizer(ARTICLE, max_length=200, min_length=20, do_sample=False))
# Out:
# [{'summary_text': "Paul Atreides is the daughter of Padishah Emperor Shaddam IV . Stilgar's Fremen troops, including Paul and his pregnant mother, Lady Jessica, secretly journals that Paul is alive . They believe the prophecy was fabricated to manipulate the Fremen . But they agree to focus on convincing the more skeptical Fremen of their prophecies ."}]

# %% [markdown]
# The model does a pretty good job for the most part. It is not perfect such as calling Paul the daughter of the Emperor in the last prompt but it is fairly concise and good at identifying the most important areas of each article. I thought it was really interesting to see how it can get a little weirder once the max_length is turned way down. I think it needs a little wiggle room to be able to make a cohesive summary as seen with 10 word max response of ```Dune: Part Two is a 20```. I was fairly impressed by how quickly and well this model performed.
